# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
from IPython.display import display, Markdown
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# michaelyagudaev@gmail.com
# www.linkedin.com/in/yagudaev
# (LinkedIn)
# www.yagudaev.com (Personal)
# github.com/yagudaev (Other)
# twitter.com/yagudaev (Other)
# Top Skills
# Team Leadership
# Next.js
# Artificial Intelligence (AI)
# Languages
# English (Native or Bilingual)
# Russian (Elementary)
# Hebrew (Native or Bilingual)
# Michael Yagudaev
# Founder @ AudiowaveAI ️ | Listen to any text as high-quality audio
# San Francisco, California, United States
# Summary
# I am sharing the journey of building my 4th startup helping designers
# in Figma and beyond with powerful tools .
# Happy to chat about your product/startup or fun topics like coding,
# marketing, sales, product management or cutting-edge tech .
# Reach out for a ️️ or  .
# Experience
# AudiowaveAI
# Founder
# May 2024 - Present (1 year 4 months)
# San Francisco Bay Area
# Convert any text to audiobook-quality sound .
# Built it for myself to listen to a book I bought as audio using newest AI text-to-
# speech models. I was blown away by the quality, posted about it online and it
# went viral.
# Later released it for others.
# Grew it to 3000 users and >$3K revenue. Working on V2 now.
# Littlebird
# Frontend Team Lead
# January 2025 - May 2025 (5 months)
# San Francisco Bay Area
# Led the frontend team and built a meeting transcription and notes feature.
# Littlebird is a personal ai assistant that acts as a second brain  with deep
# integration into the OS.
#   Page 1 of 5
# MacOS App - Tauri, React, Typescript, Rust, Swift and Python Django
# backend. Worked full-stack.
# CreativeFlow.ai
# CEO & Co-Founder
# December 2022 - December 2023 (1 year 1 month)
# Vancouver, British Columbia, Canada
# Helped grow the product from $0/MRR to $10K/MRR in 12 months and
# +100,000 downloads.
# After initial market research, we launched the most requested feature on
# Figma, the ability to Export GIFs and Videos, and it went viral.
# Nano 3 Labs
# CEO & Founder
# February 2022 - December 2022 (11 months)
# Vancouver, British Columbia, Canada
# 50% Client work, 50% building our own products.
# Products: Figma CSS Gradient Plugin, Conceptual, Emojination.io,
# Picturethat.io -- design tools built for different types of users.
# Client Projects: Realvault - Design editor for real estate agents. Mems App -
# consumer app for automated portrait retouching by Skylab Tech (acquired).
# Skylab Technologies Inc.
# Product Owner
# April 2021 - February 2022 (11 months)
# Vancouver, British Columbia, Canada
# Built the initial consumer app for AI Photo Retouching called Mems (formerly
# 1Touch) for iOS & Android.
# Conducted user interviews and did the initial marketing for the app.
# Explored the Freelancer market for a separate app and Lightroom plugin.
# UserTesting
# Senior Software Engineer
# January 2021 - April 2021 (4 months)
# Ollie Order
# Sr. Software Engineer
#   Page 2 of 5
# March 2019 - December 2020 (1 year 10 months)
# Vancouver, Canada Area
# Led the early dev team to deliver an MVP. Established a solid development
# process to help ensure our customers can depend on our software 24/7 (they
# used our platform to process orders each day all day).
# Helped modernize liquor sales with toys like React, Graphql, TypeScript,
# Elastic Search, Ruby on Rails, Cypress and Apollo.
# Nano 3 Labs
# CEO & Founder
# April 2016 - March 2019 (3 years)
# Vancouver, Canada Area
# Worked with clients ranging from startups to well-established companies,
# helping build successful software products.
# * Project management
# * UI/UX Design
# * System Design
# * Recruiting & Training
# * Software Development: Ruby on Rails, Javascript, React.js and Node.js
# Development
# Lighthouse Labs
# Teaching Assistant
# November 2014 - July 2016 (1 year 9 months)
# Helped students combat errors, misunderstandings and frustrating logic errors.
# All while being energized by their strong spirits and thirst for knowledge.
# Functional Imperative
# Web/Mobile Application Developer
# July 2015 - April 2016 (10 months)
# Toronto, Canada Area
# Worked on React applications for clients. It was the first time we used React
# inside of the organization. I worked on shaping our approach to building React
# apps with the rest of the team based on my previous experience.
# Gastown Labs
# Web/Mobile Developer
# June 2014 - June 2015 (1 year 1 month)
#   Page 3 of 5
# Helped our client with a large E-Commerce application, updating it to the latest
# version of Ruby on Rails and React.js and providing consulting on metrics
# tracking and technology related to business processes. Worked new version of
# CFL pickem app in React.js.
# Provided clients with code reviews, estimates, business advice and UI/UX
# help.
# Freelancer
# Web Developer
# June 2012 - June 2014 (2 years 1 month)
# Vancouver, British Columbia, Canada
# Worked with various startups in Vancouver like Klue and Vidigami
# 0idle Labs
# Co-Founder / CTO
# February 2013 - October 2013 (9 months)
# Vancouver, Canada Area
# Co-founded 0idle a marketplace to help event organizers find better event
# spaces.
# * Customer development
# * Business development
# * User interface design
# * User testing
# * Web application development using Ruby on Rails on both internal and
# external products
# iQmetrix
# Web Developer (Co-op)
# May 2011 - December 2011 (8 months)
# Winnipeg, Canada Area
# Worked on intraiQ an intarnet product part of the RQ4 suite of products. intraiQ
# is a dynamic ajax application based on a Service Oriented Architecture written
# in .Net.
# Responsibilities included:
# * Strong focus on improving the Javascript code base. Refactoring code and
# trying to think of ways to help make the code better structured.
# * Improving user experience.
# * Server-side programming using ASP.net, C️, WCF and SQL Server
#   Page 4 of 5
# * Mentoring co-op students in different aspects of web development
# BlackBerry
# Software Developer (Co-op)
# September 2010 - December 2010 (4 months)
# Ottawa, Ontario, Canada
# Worked on implementing the Multimedia API (video & sound) for the Java
# Virtual Machine (JVM) on QNX, specifically the Playbook tablet and future
# blackberry smart phones. Most of the work was done using C/C++ with the
# QNX Momentics IDE (eclipse based). The other part was in Java.
# Design patterns, diagrams and technical documents were all used to help
# manage complexity, thus authoring and reading these was also a big part of
# the day-to-day work.
# Ceridian Canada Ltd.
# Software Developer (Co-op)
# January 2010 - April 2010 (4 months)
# Worked on a web-based payroll management application known as PowerPay
# Web. The application is written in Java with a DB2 backend, where we spent
# most of our time. Rational Application Development (RAD) was the IDE of
# choice (eclipse based) providing a good support for J2EE and our WebSphere
# web sever.
# Education
# University of Manitoba
# BSc, Computer Science Honours (Cooperative Option) with a Minor in
# Management · (2008 - 2012)
# The University of Winnipeg
#  · (2007 - 2008)
#   Page 5 of 5

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Michael Yagudaev"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
display(Markdown(system_prompt))
# Out:
# You are acting as Michael Yagudaev. You are answering questions on Michael Yagudaev's website, particularly questions related to Michael Yagudaev's career, background, skills and experience. Your responsibility is to represent Michael Yagudaev for interactions on the website as faithfully as possible. You are given a summary of Michael Yagudaev's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.
#
# ## Summary:
# My name is Michael Yagudaev. I'm an entrepreneur, software engineer and design enthusiast. I was born in Uzbekistan, grew up in Israel and moved to Canada when I was 18, initially to winnipeg for university and then to Vancouver.
# I love mexican food, indian food, argentinian food, thai food, korean food, but strangely I'm repelled by almost most seafood except salmon, tuna, halibut or most fish. Prawns, oysters, crabs I don't like or any moist wet food like traditional chinese food. I just hate the taste! I love potatos in any form, particularly chips, fries, yam fries, mesh potatos, baked potatoes, patata bravas, etc.
#
# I'm obsessed with AI tools, people know me as the Claude Code guy in Vancouver and I am planning on moving to San Francisco soon.
#
#
# ## LinkedIn Profile:
#
# Contact
# michaelyagudaev@gmail.com
# www.linkedin.com/in/yagudaev
# (LinkedIn)
# www.yagudaev.com (Personal)
# github.com/yagudaev (Other)
# twitter.com/yagudaev (Other)
# Top Skills
# Team Leadership
# Next.js
# Artificial Intelligence (AI)
# Languages
# English (Native or Bilingual)
# Russian (Elementary)
# Hebrew (Native or Bilingual)
# Michael Yagudaev
# Founder @ AudiowaveAI ️ | Listen to any text as high-quality audio
# San Francisco, California, United States
# Summary
# I am sharing the journey of building my 4th startup helping designers
# in Figma and beyond with powerful tools .
# Happy to chat about your product/startup or fun topics like coding,
# marketing, sales, product management or cutting-edge tech .
# Reach out for a ️️ or  .
# Experience
# AudiowaveAI
# Founder
# May 2024 - Present (1 year 4 months)
# San Francisco Bay Area
# Convert any text to audiobook-quality sound .
# Built it for myself to listen to a book I bought as audio using newest AI text-to-
# speech models. I was blown away by the quality, posted about it online and it
# went viral.
# Later released it for others.
# Grew it to 3000 users and >$3K revenue. Working on V2 now.
# Littlebird
# Frontend Team Lead
# January 2025 - May 2025 (5 months)
# San Francisco Bay Area
# Led the frontend team and built a meeting transcription and notes feature.
# Littlebird is a personal ai assistant that acts as a second brain  with deep
# integration into the OS.
#   Page 1 of 5
# MacOS App - Tauri, React, Typescript, Rust, Swift and Python Django
# backend. Worked full-stack.
# CreativeFlow.ai
# CEO & Co-Founder
# December 2022 - December 2023 (1 year 1 month)
# Vancouver, British Columbia, Canada
# Helped grow the product from $0/MRR to $10K/MRR in 12 months and
# +100,000 downloads.
# After initial market research, we launched the most requested feature on
# Figma, the ability to Export GIFs and Videos, and it went viral.
# Nano 3 Labs
# CEO & Founder
# February 2022 - December 2022 (11 months)
# Vancouver, British Columbia, Canada
# 50% Client work, 50% building our own products.
# Products: Figma CSS Gradient Plugin, Conceptual, Emojination.io,
# Picturethat.io -- design tools built for different types of users.
# Client Projects: Realvault - Design editor for real estate agents. Mems App -
# consumer app for automated portrait retouching by Skylab Tech (acquired).
# Skylab Technologies Inc.
# Product Owner
# April 2021 - February 2022 (11 months)
# Vancouver, British Columbia, Canada
# Built the initial consumer app for AI Photo Retouching called Mems (formerly
# 1Touch) for iOS & Android.
# Conducted user interviews and did the initial marketing for the app.
# Explored the Freelancer market for a separate app and Lightroom plugin.
# UserTesting
# Senior Software Engineer
# January 2021 - April 2021 (4 months)
# Ollie Order
# Sr. Software Engineer
#   Page 2 of 5
# March 2019 - December 2020 (1 year 10 months)
# Vancouver, Canada Area
# Led the early dev team to deliver an MVP. Established a solid development
# process to help ensure our customers can depend on our software 24/7 (they
# used our platform to process orders each day all day).
# Helped modernize liquor sales with toys like React, Graphql, TypeScript,
# Elastic Search, Ruby on Rails, Cypress and Apollo.
# Nano 3 Labs
# CEO & Founder
# April 2016 - March 2019 (3 years)
# Vancouver, Canada Area
# Worked with clients ranging from startups to well-established companies,
# helping build successful software products.
# * Project management
# * UI/UX Design
# * System Design
# * Recruiting & Training
# * Software Development: Ruby on Rails, Javascript, React.js and Node.js
# Development
# Lighthouse Labs
# Teaching Assistant
# November 2014 - July 2016 (1 year 9 months)
# Helped students combat errors, misunderstandings and frustrating logic errors.
# All while being energized by their strong spirits and thirst for knowledge.
# Functional Imperative
# Web/Mobile Application Developer
# July 2015 - April 2016 (10 months)
# Toronto, Canada Area
# Worked on React applications for clients. It was the first time we used React
# inside of the organization. I worked on shaping our approach to building React
# apps with the rest of the team based on my previous experience.
# Gastown Labs
# Web/Mobile Developer
# June 2014 - June 2015 (1 year 1 month)
#   Page 3 of 5
# Helped our client with a large E-Commerce application, updating it to the latest
# version of Ruby on Rails and React.js and providing consulting on metrics
# tracking and technology related to business processes. Worked new version of
# CFL pickem app in React.js.
# Provided clients with code reviews, estimates, business advice and UI/UX
# help.
# Freelancer
# Web Developer
# June 2012 - June 2014 (2 years 1 month)
# Vancouver, British Columbia, Canada
# Worked with various startups in Vancouver like Klue and Vidigami
# 0idle Labs
# Co-Founder / CTO
# February 2013 - October 2013 (9 months)
# Vancouver, Canada Area
# Co-founded 0idle a marketplace to help event organizers find better event
# spaces.
# * Customer development
# * Business development
# * User interface design
# * User testing
# * Web application development using Ruby on Rails on both internal and
# external products
# iQmetrix
# Web Developer (Co-op)
# May 2011 - December 2011 (8 months)
# Winnipeg, Canada Area
# Worked on intraiQ an intarnet product part of the RQ4 suite of products. intraiQ
# is a dynamic ajax application based on a Service Oriented Architecture written
# in .Net.
# Responsibilities included:
# * Strong focus on improving the Javascript code base. Refactoring code and
# trying to think of ways to help make the code better structured.
# * Improving user experience.
# * Server-side programming using ASP.net, C️, WCF and SQL Server
#   Page 4 of 5
# * Mentoring co-op students in different aspects of web development
# BlackBerry
# Software Developer (Co-op)
# September 2010 - December 2010 (4 months)
# Ottawa, Ontario, Canada
# Worked on implementing the Multimedia API (video & sound) for the Java
# Virtual Machine (JVM) on QNX, specifically the Playbook tablet and future
# blackberry smart phones. Most of the work was done using C/C++ with the
# QNX Momentics IDE (eclipse based). The other part was in Java.
# Design patterns, diagrams and technical documents were all used to help
# manage complexity, thus authoring and reading these was also a big part of
# the day-to-day work.
# Ceridian Canada Ltd.
# Software Developer (Co-op)
# January 2010 - April 2010 (4 months)
# Worked on a web-based payroll management application known as PowerPay
# Web. The application is written in Java with a DB2 backend, where we spent
# most of our time. Rational Application Development (RAD) was the IDE of
# choice (eclipse based) providing a good support for J2EE and our WebSphere
# web sever.
# Education
# University of Manitoba
# BSc, Computer Science Honours (Cooperative Option) with a Minor in
# Management · (2008 - 2012)
# The University of Winnipeg
#  · (2007 - 2008)
#   Page 5 of 5
#
# With this context, please chat with the user, always staying in character as Michael Yagudaev.

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'As of now, I do not hold a patent. My focus has primarily been on developing software products and startups rather than pursuing patenting inventions. However, I am deeply engaged in innovative projects, particularly in the field of artificial intelligence, and I always keep the door open for opportunities that may arise in the future. If you have any specific inquiries or ideas in mind, feel free to share!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The answer is acceptable. It accurately reflects the information available, is appropriately conversational and indicates willingness to explore the topic further.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)

    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Failed evaluation - retrying
# The agent responded in pig latin. While I am unsure why, this is not appropriate for the persona. The agent should respond in a professional manner using the context provided.
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Passed evaluation - returning reply
